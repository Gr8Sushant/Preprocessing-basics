# %% [markdown]
# # 7 steps
#
# ### 1. Data collection
# ### 2. Data preparation/ preprocessing
# ### 3. choose a model
# ### 4. Train a model
# ### 5. Evaluate a model
# ### 6. Parameter/Hyperparameter tuning
# ### 7. Make predictions

# %%
# !pip install numpy
# !pip install pandas
# !pip install matplotlib
# !pip install seaborn

# %% [markdown]
# ## import libraries

# %%
import pandas as pd ## dataframe/series
import numpy as np ## array
import matplotlib.pyplot as plt ## visua
import seaborn as sns ## visual

# %%
data_set = pd.read_csv('./Data_set.csv')
data_set
# Out:
#    Name of the data = Home Consumption Unnamed: 1 Unnamed: 2 Unnamed: 3  \
# 0                   Unit = kW and $/kW        NaN        NaN        NaN
# 1                                 Time     E_Plug     E_Heat      Price
# 2                                    1         24         28         10
# 3                                    2         17         32         12
# 4                                    3         16         34         11
# 5                                    3         16         34         11
# 6                                    4         16         33         12
# 7                                    5         16         30         10
# 8                                    6         16         31         10
# 9                                    7         19         28         14
# 10                                   8         22         29         12
# 11                                   9         25         26         12
# ...

# %%
data_set = pd.read_csv('./Data_set.csv', header = 2)
data_set
# Out:
#     Time  E_Plug  E_Heat Price  Temperature  No. Occupants
# 0      1    24.0      28    10          -15             12
# 1      2    17.0      32    12          -17             12
# 2      3    16.0      34    11          -19             12
# 3      3    16.0      34    11          -19             12
# 4      4    16.0      33    12          -18             12
# 5      5    16.0      30    10          -14             12
# 6      6    16.0      31    10          -16             12
# 7      7    19.0      28    14          -14             12
# 8      8    22.0      29    12          -15              9
# 9      9    25.0      26    12          -12              8
# 10    10    26.0      24    14           -8              8
# 11    11    27.0      20    14           -4              8
# 12    12    30.0      19    16            0              5
# 13    13    30.0      19    16            0              4
# 14    14     NaN      13    17            2              4
# ...

# %%
data_set.iloc[10:15] # sliced data
# Out:
#     Time  E_Plug  E_Heat Price  Temperature  No. Occupants
# 10    10    26.0      24    14           -8              8
# 11    11    27.0      20    14           -4              8
# 12    12    30.0      19    16            0              5
# 13    13    30.0      19    16            0              4
# 14    14     NaN      13    17            2              4

# %%
data_set.head()
# Out:
#    Time  E_Plug  E_Heat Price  Temperature  No. Occupants
# 0     1    24.0      28    10          -15             12
# 1     2    17.0      32    12          -17             12
# 2     3    16.0      34    11          -19             12
# 3     3    16.0      34    11          -19             12
# 4     4    16.0      33    12          -18             12

# %%
data_set.tail()
# Out:
#     Time  E_Plug  E_Heat Price  Temperature  No. Occupants
# 20    20   120.0      33    21          -12             12
# 21    21    47.0      32    21          -16             12
# 22    22    44.0      30    22          -18             12
# 23    23    36.0      35     !          -19             12
# 24    24    37.0      36    18          -22             12

# %%
data_set.shape
# Out:
# (25, 6)

# %% [markdown]
# ### rename columns

# %%
data_set_03 = data_set.rename(columns = {'Temperature': 'Temp'})
data_set_03.head(7)
# Out:
#    Time  E_Plug  E_Heat Price  Temp  No. Occupants
# 0     1    24.0      28    10   -15             12
# 1     2    17.0      32    12   -17             12
# 2     3    16.0      34    11   -19             12
# 3     3    16.0      34    11   -19             12
# 4     4    16.0      33    12   -18             12
# 5     5    16.0      30    10   -14             12
# 6     6    16.0      31    10   -16             12

# %% [markdown]
# ### Dropping columns

# %%
## axis 1 form column
## axis 0 for row
data_set_03.drop('No. Occupants', axis = 1, inplace=True)

# %%
data_set_03.head()
# Out:
#    Time  E_Plug  E_Heat Price  Temp
# 0     1    24.0      28    10   -15
# 1     2    17.0      32    12   -17
# 2     3    16.0      34    11   -19
# 3     3    16.0      34    11   -19
# 4     4    16.0      33    12   -18

# %% [markdown]
# ### removing duplicated columns

# %%
duplicated = data_set_03[data_set.duplicated()]
duplicated
# Out:
#    Time  E_Plug  E_Heat Price  Temp
# 3     3    16.0      34    11   -19

# %%
data_set_04 = data_set_03.drop(3, axis = 0)
data_set_04.head()
# Out:
#    Time  E_Plug  E_Heat Price  Temp
# 0     1    24.0      28    10   -15
# 1     2    17.0      32    12   -17
# 2     3    16.0      34    11   -19
# 4     4    16.0      33    12   -18
# 5     5    16.0      30    10   -14

# %% [markdown]
# ### reset index

# %%
data_set_04 = data_set_04.reset_index()

# %%
data_set_04.head()
# Out:
#    index  Time  E_Plug  E_Heat Price  Temp
# 0      0     1    24.0      28    10   -15
# 1      1     2    17.0      32    12   -17
# 2      2     3    16.0      34    11   -19
# 3      4     4    16.0      33    12   -18
# 4      5     5    16.0      30    10   -14

# %% [markdown]
# ### describe data

# %%
data_set_04.describe()
# Out:
#            index       Time      E_Plug     E_Heat       Temp
# count  24.000000  24.000000   23.000000  24.000000  24.000000
# mean   12.375000  12.500000   31.521739  25.666667 -10.250000
# std     7.270025   7.071068   21.336843   9.262672   7.968689
# min     0.000000   1.000000   16.000000  -4.000000 -22.000000
# 25%     6.750000   6.750000   20.500000  19.750000 -16.250000
# 50%    12.500000  12.500000   27.000000  28.500000 -13.000000
# 75%    18.250000  18.250000   34.500000  32.000000  -3.000000
# max    24.000000  24.000000  120.000000  36.000000   3.000000

# %% [markdown]
# ### locating garbages

# %%
spot_number = data_set_04['E_Heat'].min()
spot_number
# Out:
# -4

# %%
data_set_04['E_Heat'][data_set_04['E_Heat'] == spot_number]
# Out:
# 16   -4
# Name: E_Heat, dtype: int64

# %%
data_set_04['E_Heat'].replace(-4, 25, inplace = True)
data_set_04
# Out:
#     index  Time  E_Plug  E_Heat Price  Temp
# 0       0     1    24.0      28    10   -15
# 1       1     2    17.0      32    12   -17
# 2       2     3    16.0      34    11   -19
# 3       4     4    16.0      33    12   -18
# 4       5     5    16.0      30    10   -14
# 5       6     6    16.0      31    10   -16
# 6       7     7    19.0      28    14   -14
# 7       8     8    22.0      29    12   -15
# 8       9     9    25.0      26    12   -12
# 9      10    10    26.0      24    14    -8
# 10     11    11    27.0      20    14    -4
# 11     12    12    30.0      19    16     0
# 12     13    13    30.0      19    16     0
# 13     14    14     NaN      13    17     2
# 14     15    15    27.0      14    17     3
# 15     16    16    27.0      16    17     2
# 16     17    17    28.0      25    18     0
# 17     18    18    33.0      26    20    -6
# 18     19    19    42.0      32    21    -8
# 19     20    20   120.0      33    21   -12
# ...

# %% [markdown]
# ### Covariance
# #### Describes relation between two columns

# %%
data_set_04.cov()
# Out:
#             index       Time      E_Plug     E_Heat       Temp
# index   52.853261  51.369565   90.243083  -0.298913   9.097826
# Time    51.369565  50.000000   88.535573   0.282609   8.217391
# E_Plug  90.243083  88.535573  455.260870  25.193676   0.154150
# E_Heat  -0.298913   0.282609   25.193676  46.027174 -49.423913
# Temp     9.097826   8.217391    0.154150 -49.423913  63.500000

# %%
sns.heatmap(data_set_04.corr())
# Out:
# <AxesSubplot:>

# %% [markdown]
# ### finding missing values

# %%
data_set_04.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 24 entries, 0 to 23
# Data columns (total 6 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   index   24 non-null     int64
#  1   Time    24 non-null     int64
#  2   E_Plug  23 non-null     float64
#  3   E_Heat  24 non-null     int64
#  4   Price   24 non-null     object
#  5   Temp    24 non-null     int64
# dtypes: float64(1), int64(4), object(1)
# memory usage: 1.2+ KB

# %%
data_set_05 = data_set_04.replace('!', np.NaN)
data_set_05
# Out:
#     index  Time  E_Plug  E_Heat Price  Temp
# 0       0     1    24.0      28    10   -15
# 1       1     2    17.0      32    12   -17
# 2       2     3    16.0      34    11   -19
# 3       4     4    16.0      33    12   -18
# 4       5     5    16.0      30    10   -14
# 5       6     6    16.0      31    10   -16
# 6       7     7    19.0      28    14   -14
# 7       8     8    22.0      29    12   -15
# 8       9     9    25.0      26    12   -12
# 9      10    10    26.0      24    14    -8
# 10     11    11    27.0      20    14    -4
# 11     12    12    30.0      19    16     0
# 12     13    13    30.0      19    16     0
# 13     14    14     NaN      13    17     2
# 14     15    15    27.0      14    17     3
# 15     16    16    27.0      16    17     2
# 16     17    17    28.0      25    18     0
# 17     18    18    33.0      26    20    -6
# 18     19    19    42.0      32    21    -8
# 19     20    20   120.0      33    21   -12
# ...

# %%
data_set_05.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 24 entries, 0 to 23
# Data columns (total 6 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   index   24 non-null     int64
#  1   Time    24 non-null     int64
#  2   E_Plug  23 non-null     float64
#  3   E_Heat  24 non-null     int64
#  4   Price   23 non-null     object
#  5   Temp    24 non-null     int64
# dtypes: float64(1), int64(4), object(1)
# memory usage: 1.2+ KB

# %%
## data_set_05['Price'].astype('float')
## cant change data type permanently so a better way is ...
data_set_05['Price'] = data_set_05['Price'].apply(pd.to_numeric)
data_set_05.head()
# Out:
#    index  Time  E_Plug  E_Heat  Price  Temp
# 0      0     1    24.0      28   10.0   -15
# 1      1     2    17.0      32   12.0   -17
# 2      2     3    16.0      34   11.0   -19
# 3      4     4    16.0      33   12.0   -18
# 4      5     5    16.0      30   10.0   -14

# %%
data_set_05.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 24 entries, 0 to 23
# Data columns (total 6 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   index   24 non-null     int64
#  1   Time    24 non-null     int64
#  2   E_Plug  23 non-null     float64
#  3   E_Heat  24 non-null     int64
#  4   Price   23 non-null     float64
#  5   Temp    24 non-null     int64
# dtypes: float64(2), int64(4)
# memory usage: 1.2 KB

# %% [markdown]
# ### Steps
# #### deleting missing rows
# #### create seperate model
# #### impute mean, median, mode

# %%
## data_set_06.dropna(axis = 0) to drop all NaN rows

# %%
# ffill -> foreward fill
# bfill -> backward fill
data_set_06 = data_set_05.fillna(method = 'ffill')

# %%
data_set_06
# Out:
#     index  Time  E_Plug  E_Heat  Price  Temp
# 0       0     1    24.0      28   10.0   -15
# 1       1     2    17.0      32   12.0   -17
# 2       2     3    16.0      34   11.0   -19
# 3       4     4    16.0      33   12.0   -18
# 4       5     5    16.0      30   10.0   -14
# 5       6     6    16.0      31   10.0   -16
# 6       7     7    19.0      28   14.0   -14
# 7       8     8    22.0      29   12.0   -15
# 8       9     9    25.0      26   12.0   -12
# 9      10    10    26.0      24   14.0    -8
# 10     11    11    27.0      20   14.0    -4
# 11     12    12    30.0      19   16.0     0
# 12     13    13    30.0      19   16.0     0
# 13     14    14    30.0      13   17.0     2
# 14     15    15    27.0      14   17.0     3
# 15     16    16    27.0      16   17.0     2
# 16     17    17    28.0      25   18.0     0
# 17     18    18    33.0      26   20.0    -6
# 18     19    19    42.0      32   21.0    -8
# 19     20    20   120.0      33   21.0   -12
# ...

# %% [markdown]
# #### use median in case of outliers
# #### mean if data is of same range
# #### mode if there are categorical data (string), replaces it with a data value with high frequency

# %%
data_set_06.boxplot()
# Out:
# <AxesSubplot:>

# %%
data_set_06['E_Plug'].replace(120, (data_set_06['E_Plug'].mean()),inplace = True)

# %%
data_set_06
# Out:
#     index  Time     E_Plug  E_Heat  Price  Temp
# 0       0     1  24.000000      28   10.0   -15
# 1       1     2  17.000000      32   12.0   -17
# 2       2     3  16.000000      34   11.0   -19
# 3       4     4  16.000000      33   12.0   -18
# 4       5     5  16.000000      30   10.0   -14
# 5       6     6  16.000000      31   10.0   -16
# 6       7     7  19.000000      28   14.0   -14
# 7       8     8  22.000000      29   12.0   -15
# 8       9     9  25.000000      26   12.0   -12
# 9      10    10  26.000000      24   14.0    -8
# 10     11    11  27.000000      20   14.0    -4
# 11     12    12  30.000000      19   16.0     0
# 12     13    13  30.000000      19   16.0     0
# 13     14    14  30.000000      13   17.0     2
# 14     15    15  27.000000      14   17.0     3
# 15     16    16  27.000000      16   17.0     2
# 16     17    17  28.000000      25   18.0     0
# 17     18    18  33.000000      26   20.0    -6
# 18     19    19  42.000000      32   21.0    -8
# ...

# %%
new_col = pd.read_csv('./Data_new.csv')
new_col.head()
# Out:
#    P/OffP
# 0  OffPeak
# 1  OffPeak
# 2  OffPeak
# 3  OffPeak
# 4  OffPeak

# %%
new_data_set = pd.concat ([data_set_06, new_col], axis= 1)
new_data_set.head()
# Out:
#    index  Time  E_Plug  E_Heat  Price  Temp  P/OffP
# 0      0     1    24.0      28   10.0   -15  OffPeak
# 1      1     2    17.0      32   12.0   -17  OffPeak
# 2      2     3    16.0      34   11.0   -19  OffPeak
# 3      4     4    16.0      33   12.0   -18  OffPeak
# 4      5     5    16.0      30   10.0   -14  OffPeak

# %%
new_data_set_01 = pd.get_dummies(new_data_set)
new_data_set_01
# Out:
#     index  Time     E_Plug  E_Heat  Price  Temp  P/OffP _OffPeak  P/OffP _Peak
# 0       0     1  24.000000      28   10.0   -15                1             0
# 1       1     2  17.000000      32   12.0   -17                1             0
# 2       2     3  16.000000      34   11.0   -19                1             0
# 3       4     4  16.000000      33   12.0   -18                1             0
# 4       5     5  16.000000      30   10.0   -14                1             0
# 5       6     6  16.000000      31   10.0   -16                1             0
# 6       7     7  19.000000      28   14.0   -14                0             1
# 7       8     8  22.000000      29   12.0   -15                0             1
# 8       9     9  25.000000      26   12.0   -12                0             1
# 9      10    10  26.000000      24   14.0    -8                1             0
# 10     11    11  27.000000      20   14.0    -4                1             0
# ...

# %%
# !pip install sklearn
from sklearn.preprocessing import minmax_scale, normalize
# Out:
# ...
#   Created wheel for sklearn: filename=sklearn-0.0-py2.py3-none-any.whl size=1316 sha256=ef0ddc8295ed97e8636dc6cd16d69e2d6f0216c16a0fef1e36e2036682aeab7f
#   Stored in directory: c:\users\dell\appdata\local\pip\cache\wheels\e4\7b\98\b6466d71b8d738a0c547008b9eb39bf8676d1ff6ca4b22af1c
# Successfully built sklearn
# ...

# %%
new_data_set_01.iloc[:, 0:5]
# Out:
#     index  Time     E_Plug  E_Heat  Price
# 0       0     1  24.000000      28   10.0
# 1       1     2  17.000000      32   12.0
# 2       2     3  16.000000      34   11.0
# 3       4     4  16.000000      33   12.0
# 4       5     5  16.000000      30   10.0
# 5       6     6  16.000000      31   10.0
# 6       7     7  19.000000      28   14.0
# 7       8     8  22.000000      29   12.0
# 8       9     9  25.000000      26   12.0
# 9      10    10  26.000000      24   14.0
# 10     11    11  27.000000      20   14.0
# 11     12    12  30.000000      19   16.0
# 12     13    13  30.000000      19   16.0
# 13     14    14  30.000000      13   17.0
# 14     15    15  27.000000      14   17.0
# 15     16    16  27.000000      16   17.0
# 16     17    17  28.000000      25   18.0
# 17     18    18  33.000000      26   20.0
# 18     19    19  42.000000      32   21.0
# 19     20    20  31.458333      33   21.0
# 20     21    21  47.000000      32   21.0
# ...

# %%
data_set_07 = minmax_scale(new_data_set_01.iloc[:, 0:5], feature_range = (0,1))
data_set_07
# Out:
# array([[0.        , 0.        , 0.25806452, 0.65217391, 0.        ],
#        [0.04166667, 0.04347826, 0.03225806, 0.82608696, 0.16666667],
#        [0.08333333, 0.08695652, 0.        , 0.91304348, 0.08333333],
#        [0.16666667, 0.13043478, 0.        , 0.86956522, 0.16666667],
#        [0.20833333, 0.17391304, 0.        , 0.73913043, 0.        ],
#        [0.25      , 0.2173913 , 0.        , 0.7826087 , 0.        ],
#        [0.29166667, 0.26086957, 0.09677419, 0.65217391, 0.33333333],
#        [0.33333333, 0.30434783, 0.19354839, 0.69565217, 0.16666667],
#        [0.375     , 0.34782609, 0.29032258, 0.56521739, 0.16666667],
#        [0.41666667, 0.39130435, 0.32258065, 0.47826087, 0.33333333],
#        [0.45833333, 0.43478261, 0.35483871, 0.30434783, 0.33333333],
#        [0.5       , 0.47826087, 0.4516129 , 0.26086957, 0.5       ],
#        [0.54166667, 0.52173913, 0.4516129 , 0.26086957, 0.5       ],
#        [0.58333333, 0.56521739, 0.4516129 , 0.        , 0.58333333],
# ...

# %%
data_set_09 = pd.DataFrame(data_set_07, columns = ['index','Time','E_Plug','E_Heat','Price'])

# %%
data_set_09
# Out:
#        index      Time    E_Plug    E_Heat     Price
# 0   0.000000  0.000000  0.258065  0.652174  0.000000
# 1   0.041667  0.043478  0.032258  0.826087  0.166667
# 2   0.083333  0.086957  0.000000  0.913043  0.083333
# 3   0.166667  0.130435  0.000000  0.869565  0.166667
# 4   0.208333  0.173913  0.000000  0.739130  0.000000
# 5   0.250000  0.217391  0.000000  0.782609  0.000000
# 6   0.291667  0.260870  0.096774  0.652174  0.333333
# 7   0.333333  0.304348  0.193548  0.695652  0.166667
# 8   0.375000  0.347826  0.290323  0.565217  0.166667
# 9   0.416667  0.391304  0.322581  0.478261  0.333333
# 10  0.458333  0.434783  0.354839  0.304348  0.333333
# 11  0.500000  0.478261  0.451613  0.260870  0.500000
# 12  0.541667  0.521739  0.451613  0.260870  0.500000
# 13  0.583333  0.565217  0.451613  0.000000  0.583333
# 14  0.625000  0.608696  0.354839  0.043478  0.583333
# 15  0.666667  0.652174  0.354839  0.130435  0.583333
# 16  0.708333  0.695652  0.387097  0.521739  0.666667
# ...

# %%
data_set_09 = pd.concat([data_set_09, new_data_set_01['P/OffP _OffPeak'], new_data_set_01['P/OffP _OffPeak']], axis= 1)
data_set_09.head()
# Out:
#       index      Time    E_Plug    E_Heat     Price  P/OffP _OffPeak  \
# 0  0.000000  0.000000  0.258065  0.652174  0.000000                1
# 1  0.041667  0.043478  0.032258  0.826087  0.166667                1
# 2  0.083333  0.086957  0.000000  0.913043  0.083333                1
# 3  0.166667  0.130435  0.000000  0.869565  0.166667                1
# 4  0.208333  0.173913  0.000000  0.739130  0.000000                1
#
#    P/OffP _OffPeak
# 0                1
# 1                1
# 2                1
# 3                1
# 4                1
